# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
mcd = pd.read_csv('mcdonalds.csv',index_col='Date',parse_dates=True)

# %%
mcd.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1970-01-02    0.209761    2825604.0
# 1970-01-05    0.213316    2210449.5
# 1970-01-06    0.214501    1951168.5
# 1970-01-07    0.213316    2728768.5
# 1970-01-08    0.213316    2242404.0

# %%
mcd['Adj. Close'].plot(figsize=(15,5))
# Out:
# <img src="data:image/png;base64,..." width="1080">
# <AxesSubplot:xlabel='Date'>

# %%
mcd['Adj. Volume'].plot(figsize=(15,5),c='Red')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mcd['Adj. Close'].plot(xlim=['2009-01-01','2015-01-01'],ylim=(0,100),c='Purple')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import matplotlib.dates as dates

# %%
mcd['Adj. Close'].plot(xlim=['2009-01-01','2015-01-01'],ylim=(0,100),c='Orange')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
idx = mcd.loc['2009-01-01':'2015-01-01'].index

# %%
idx
# Out:
# DatetimeIndex(['2009-01-02', '2009-01-05', '2009-01-06', '2009-01-07',
#                '2009-01-08', '2009-01-09', '2009-01-12', '2009-01-13',
#                '2009-01-14', '2009-01-15',
#                ...
#                '2014-12-17', '2014-12-18', '2014-12-19', '2014-12-22',
#                '2014-12-23', '2014-12-24', '2014-12-26', '2014-12-29',
#                '2014-12-30', '2014-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1510, freq=None)

# %%
stock = mcd.loc['2009-01-01':'2015-01-01']['Adj. Close']

# %%
stock
# Out:
# Date
# 2009-01-02    48.551982
# 2009-01-05    48.407278
# 2009-01-06    47.325806
# 2009-01-07    46.640367
# 2009-01-08    46.092015
#                 ...
# 2014-12-24    86.816171
# 2014-12-26    87.695158
# 2014-12-29    87.935723
# 2014-12-30    87.204776
# 2014-12-31    86.695888
# Name: Adj. Close, Length: 1510, dtype: float64

# %%
stock.plot(c='Grey')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fig,ax = plt.subplots()
ax.plot_date(idx,stock,'-')
ax.yaxis.grid(True)
ax.xaxis.grid(True)
fig.autofmt_xdate()
